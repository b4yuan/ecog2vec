# %%
import tensorflow as tf
import os
from machine_learning.neural_networks import tf_helpers as tfh
import pdb

from pynwb import NWBHDF5IO
import numpy as np
import os
import torch
import soundfile as sf
import scipy.stats
from process_nwb.resample import resample as resample_nwb
from scipy.stats.mstats import zscore
import samplerate

# Creating a list of dictionaries of:
# 
# `ecog_sequence`: ECoG data, clipped to token(-sequence) length
# `text_sequence`: the corresponding text token(-sequence)
# `audio_sequence`: the corresponding audio (MFCC) token sequence (gonna set to)
# `phoneme_sequence`: ditto for phonemes--with repeats
#
# Then saving them as tf_records

def transcription_to_array(trial_t0, trial_tF, onset_times, offset_times, transcription, max_length, sampling_rate):
    
    # if the transcription is missing (e.g. for covert trials)
    if transcription is None:
        return np.full(max_length, 'pau', dtype='<U5')

    # get just the parts of transcript relevant to this trial
    trial_inds = (onset_times >= trial_t0) * (offset_times < trial_tF)
    transcript = np.array(transcription.description.split(' '))[trial_inds]
    onset_times = np.array(onset_times[trial_inds])
    offset_times = np.array(offset_times[trial_inds])

    # vectorized indexing
    sample_times = trial_t0 + np.arange(max_length)/sampling_rate
    indices = (
        (sample_times[None, :] >= onset_times[:, None]) *
        (sample_times[None, :] < offset_times[:, None])
    )

    # no more than one phoneme should be on at once...
    try:
        # print('exactly one phoneme:', np.all(np.sum(indices, 0) == 1))
        assert np.all(np.sum(indices, 0) < 2)
    except:
        pdb.set_trace()

    # ...but there can be locations with *zero* phonemes; assume 'pau' here
    transcript = np.insert(transcript, 0, 'pau')
    indices = np.sum(indices*(np.arange(1, len(transcript))[:, None]), 0)

    return transcript[indices]

def sentence_tokenize(token_list): # token_type = word_sequence
    tokenized_sentence = [
                (token.lower() + '_').encode('utf-8') for token in token_list
            ]
    return tokenized_sentence

def write_to_Protobuf(path, example_dicts):
    '''
    Collect the relevant ECoG data and then write to disk as a (google)
        protocol buffer.
    '''
    writer = tf.io.TFRecordWriter(
        path)
    for example_dict in example_dicts:
        feature_example = tfh.make_feature_example(example_dict)
        writer.write(feature_example.SerializeToString())
            
# sorting function for latent representation filenames, NOT USED FOR THIS
# def custom_sort_key(filename):
#     num_part = int(filename.split('nwb_')[1].split('.wav.pt')[0])
#     return num_part

def resample(
    data, source_to_target_ratio, ZSCORE, resample_method='sinc_best',
    N_channels_max=128
):

    ######################
    # If downsampling by an integer, just anti-alias and subsample??
    ######################

    # 128 is the max for the underlying library
    N_channels_max = min(N_channels_max, 128)
    N_channels = data.shape[1]
    data_mat = None

    for i0 in np.arange(0, N_channels, N_channels_max):
        iF = np.min((i0+N_channels_max, N_channels))
        resampler = samplerate.Resampler(resample_method, channels=iF-i0)
        data_chunk = resampler.process(
            data[:, i0:iF], 1/source_to_target_ratio, end_of_input=True
        )
        data_mat = (
            data_chunk if data_mat is None else
            np.concatenate((data_mat, data_chunk), axis=1)
        )
    if ZSCORE:
        data_mat = zscore(data_mat)

    return data_mat

def downsample(data, rate_source, rate_target, ZSCORE=False):
    return downsample_NWB(data, rate_source, rate_target, ZSCORE=ZSCORE)
    # return resample(data, rate_source/rate_target, ZSCORE=ZSCORE)

def downsample_NWB(data, rate_source, rate_target, ZSCORE=False):
    '''
    Downsample data from rate_source to rate_target using process_NWB methods

    Input arguments:
    --------
    data:
        an ndarray of the data to downsample (Nsamples_source, Nchannels)
    source_rate:
        the sampling rate of the input data
    rate_target:
        the sampling rate of the output data

    Returns:
    --------
    X:
        An ndarray (Nsamples_source, Nchannels) of the downsampled data
    '''

    # Note: zero padding is done in resample
 
    # downsampling
    print("Downsampling signals to %s Hz; please wait..." % rate_target)
    Nsamples_source, Nchannels = data.shape
    ##############
    # 1e6 scaling helps with numerical accuracy
    # scale = 1e6
    scale = 1
    # Is this true??
    ##############
    
    # malloc
    Nsamples_target = int(np.ceil(Nsamples_source*rate_target/rate_source))
    X = np.zeros((Nsamples_target, Nchannels))

    # One channel at a time, to improve memory usage for long signals
    for ch in np.arange(Nchannels):
        X[:, ch] = resample_nwb(data[:, ch]*scale, rate_target, rate_source)
    X = X/scale

    if ZSCORE:
        X = scipy.stats.mstats.zscore(X)

    return X

# Removing bad electrodes

def elec_layout(grid_size, grid_step):
    layout = np.arange(np.prod(
        grid_size)-1, -1, -1).reshape(grid_size).T

    # now correct for subsampling the grid
    return layout[::grid_step, ::grid_step]
    
def good_electrodes(grid_size, bad_electrodes):
    '''
    NB!!! bad_electrodes are 1-indexed, good_electrodes are zero-indexed!!

    Since this is a set, it contains no order information.  The canonical
    ordering is established with good_channels, since after all the data
    size is (... x Nchannels),  not (... x Nelectrodes).
    '''

    # bad_electrodes = [int(e.strip()) for e in bad_electrodes]
    return (
        set(range(np.prod(grid_size))) -
        set(np.array(bad_electrodes)-1)
    )
    
def bipolar_to_elec_map(layout):
    # print('WARNING!!!!  MAKING UP bipolar_to_elec_map!!!')
    elec_map = []
    # layout = self.elec_layout  # for short
    for i in range(layout.shape[0]):
        for j in range(layout.shape[1]):
            if j < layout.shape[1]-1:
                elec_map.append((layout[i, j], layout[i, j+1]))
            if i < layout.shape[0]-1:
                elec_map.append((layout[i, j], layout[i+1, j]))
    return np.array(elec_map)
    
def good_channels(elec_layout, bipolar_to_elec_map, good_electrodes):
    '''
    Pseudo-channels, constructed (on the fly) from the physical electrodes.
    For now at least, we won't USE_FIELD_POTENTIALS if we want to
    REFERENCE_BIPOLAR.

    NB!!: The *order* of these channels matters--it determines the order of
    the input data, and therefore is required by the functions that plot
    electrode_contributions in plotters.py! And the order of these channels
    will be determined by the *elec_layout*.
    '''

    # NB: this means that the electrodes are *not* in numerical order ('e1'
    #  does not correspond to the 0th entry in all_electrodes): as you can
    #  check, flattening the elec_layout does not yield an ordered list.
    all_electrodes = elec_layout.flatten().tolist()

    # if self.USE_FIELD_POTENTIALS:
    #     M = len(all_electrodes)
    #     return (
    #         [e for e in all_electrodes if e in self.good_electrodes] +
    #         [e+M for e in all_electrodes if e in self.good_electrodes]
    #     )
    # elif self.REFERENCE_BIPOLAR:
    return [
        ch for ch, elec_pair in enumerate(bipolar_to_elec_map)
        if all([e in good_electrodes for e in elec_pair])
    ]
    # else:
    #     return [e for e in all_electrodes if e in self.good_electrodes]
# Out:
# 2023-12-16 11:12:10.585811: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-16 11:12:10.585840: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-16 11:12:10.586854: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-16 11:12:10.591675: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-16 11:12:11.167485: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: tensor2tensor not found; skipping

# %%
import matplotlib.pyplot as plt
from scipy.signal import butter, lfilter, filtfilt, hilbert
from scipy.fft import fft, ifft

all_example_dict = []
patient = 'EFC400'
blocks = [3, 23, 72]
        # [4, 41, 57, 61, 66, 69, 73, 77, 83, 87] # [3,4,6,8,10,12,14,15,19,23,28,30,38,40,42,46,57,61,72] # change this for what tf_record you're making
_bad_electrodes = [1, 2, 33, 50, 54, 64, 128, 129, 193, 194, 256]
    #[1,2,63,64,65,127,143,193,194,195,196,235,239,243,252,254,255,256]
# bad_electrodes = [i - 1 for i in bad_electrodes]
# good_electrodes = [x for x in list(np.arange(256)) if x not in bad_electrodes]

grid_size = np.array([16, 16])
grid_step = 1

_good_electrodes = good_electrodes(grid_size, _bad_electrodes)
_elec_layout = elec_layout(grid_size, grid_step)
_bipolar_to_elec_map = bipolar_to_elec_map(_elec_layout)

# print(_bad_electrodes)
# print(_good_electrodes)

_good_channels = good_channels(_elec_layout, _bipolar_to_elec_map, _good_electrodes)

# print(len(_good_channels))
for block in blocks:

    tfrecord_path = f'/home/bayuan/Documents/fall23/ecog2vec/wav2vec_tfrecords/ecog2txt/word_sequence/tf_records_orig_400/{patient}_B{block}.tfrecord'

    nwb_filepath = folder_path = f"/NWB/{patient}/{patient}_B{block}.nwb"
    io = NWBHDF5IO(nwb_filepath, load_namespaces=True, mode='r')
    nwbfile = io.read()
    
    electrode_table = nwbfile.acquisition['ElectricalSeries'].\
                                        electrodes.table[:]

    indices = np.where(np.logical_or(electrode_table['group_name'] == 
                                        'L256GridElectrode electrodes', 
                                        electrode_table['group_name'] == 
                                        'R256GridElectrode electrodes'))[0]

    raw_data = nwbfile.acquisition['ElectricalSeries'].\
                                    data[:,indices]
                                    
    raw_data = raw_data[:,sorted(list(_good_electrodes))]
                    
    # high_gamma = downsample(high_gamma, 400, 200, ZSCORE=True)
    
    nwb_sr = nwbfile.acquisition['ElectricalSeries'].\
                                rate
    
    w_l = 70 / (nwb_sr / 2) # Normalize the frequency
    w_h = 200 / (nwb_sr / 2)
    b, a = butter(5, [w_l,w_h], 'band')
    
    for ch in range(raw_data.shape[1]):
        raw_data[:,ch] = filtfilt(b, 
                                a, 
                                raw_data[:,ch])
        
        #analytic amp
        raw_data[:,ch] = np.abs(hilbert(raw_data[:,ch]))
        
    high_gamma = raw_data
    
    phoneme_transcriptions = nwbfile.processing['behavior'].data_interfaces['BehavioralEpochs'].interval_series #['phoneme transcription'].timestamps[:]

    token_type = 'word_sequence'

    max_seconds_dict = {
        'phoneme': 0.2,
        'word': 1.0,
        'word_sequence': 6.25,
        'word_piece_sequence': 6.25,
        'phoneme_sequence': 6.25,
        'trial': 6.25
    }

    if 'phoneme transcription' in phoneme_transcriptions:
        print(f'Phoneme transcription for block {block} exists.')
        phoneme_transcript = phoneme_transcriptions['phoneme transcription']
        phoneme_onset_times = phoneme_transcript.timestamps[
            phoneme_transcript.data[()] == 1]
        phoneme_offset_times = phoneme_transcript.timestamps[
            phoneme_transcript.data[()] == -1]
    else:
        phoneme_transcript = None
        phoneme_onset_times = None
        phoneme_offset_times = None

    example_dicts = []

    makin_sr = 101.7 # 200
    
    
    high_gamma = downsample(high_gamma, nwb_sr, makin_sr, ZSCORE=True)
    
    # starts = list(nwbfile.trials[:]['start_time']) # * nwb_sr)
    # stops = list(nwbfile.trials[:]['stop_time']) # * nwb_sr)
    
    # print(starts[0], stops[0])

    for index, trial in enumerate(nwbfile.trials):
        t0 = float(trial.iloc[0].start_time)
        tF = float(trial.iloc[0].stop_time)
    
        i0 = np.rint(makin_sr*t0).astype(int)
        iF = np.rint(makin_sr*tF).astype(int)
        
        # ECOG (C) SEQUENCE
        c = high_gamma[i0:iF,:]
        # print(c.shape)
        # plt.plot(c[:,0])
        # break
    
        print(c.shape)
        nsamples = c.shape[0]
        
        # TEXT SEQUENCE
        speech_string = trial['transcription'].values[0]
        text_sequence = sentence_tokenize(speech_string.split(' ')) # , 'text_sequence')
        
        # AUDIO SEQUENCE    
        audio_sequence = []
        
        # PHONEME SEQUENCE
        
        M = iF - i0
        
        max_seconds = max_seconds_dict.get(token_type) # , 0.2) # i don't think this 0.2 default is necessary for the scope of this
        max_samples = int(np.floor(makin_sr*max_seconds))
        max_length = min(M, max_samples)
        
        phoneme_array = transcription_to_array(
                        t0, tF, phoneme_onset_times, phoneme_offset_times,
                        phoneme_transcript, max_length, makin_sr
                    )
        
        phoneme_sequence = [ph.encode('utf-8') for ph in phoneme_array]
        
        if len(phoneme_sequence) != nsamples:
            if len(phoneme_sequence) > nsamples:
                phoneme_sequence = [phoneme_sequence[i] for i in range(nsamples)]
            else:
                for i in range(nsamples - len(phoneme_sequence)):
                    phoneme_sequence.append(phoneme_sequence[len(phoneme_sequence) - 1])
        
        print('\n------------------------')
        print(f'For sentence {index}: ')
        print(c[0:5,0:5])
        print(f'Latent representation shape: {c.shape} (should be [samples, nchannel])')
        print(text_sequence)
        print(f'Audio sequence: {audio_sequence}')
        print(f'Length of phoneme sequence: {len(phoneme_sequence)}')
        print(phoneme_sequence)
        print('------------------------\n')
        
        example_dicts.append({'ecog_sequence': c, 'text_sequence': text_sequence, 'audio_sequence': [], 'phoneme_sequence': phoneme_sequence,})
        
        
        # break
    
    # break
        
    all_example_dict.extend(example_dicts)
    print(len(example_dicts))
    print(len(all_example_dict))
    write_to_Protobuf(tfrecord_path, example_dicts)

print(len(all_example_dict))
# Out:
# /home/bayuan/anaconda3/envs/ecog2txt/lib/python3.9/site-packages/hdmf/spec/namespace.py:531: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/bayuan/anaconda3/envs/ecog2txt/lib/python3.9/site-packages/hdmf/spec/namespace.py:531: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# Phoneme transcription for block 3 exists.
# Downsampling signals to 101.7 Hz; please wait...
# (138, 245)
#
# ------------------------
# For sentence 0:
# [[ 0.07585072  0.31488337  0.23808057  0.30820591  0.98758648]
#  [-1.64120539 -1.84417401 -1.73916661 -1.36783566  1.9998449 ]
#  [-0.41667863  0.0694105   0.21159387 -0.48622319  0.36795554]
#  [-1.94118787 -1.91691413 -1.6200376  -0.41769632  0.96471845]
#  [ 0.68023269  1.05807324  1.71942254  2.48887566 -0.6908969 ]]
# Latent representation shape: (138, 245) (should be [samples, nchannel])
# [b'this_', b'was_', b'easy_', b'for_', b'us_']
# Audio sequence: []
# Length of phoneme sequence: 138
# [b'dh', b'dh', b'dh', b'dh', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'w', b'aa', b'aa', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's']
# ------------------------
#
# (228, 245)
#
# ------------------------
# For sentence 1:
# [[ 0.73759668  1.01051034  0.91346511  1.0810946  -0.47882504]
#  [ 0.66226602 -0.18634607 -0.07756325 -1.45170527 -0.40950854]
#  [-1.99851513 -1.52117804 -1.58716013 -1.30105881 -0.57944229]
#  [-0.48520237  0.09217584 -0.08055618  0.92404563  1.28391638]
#  [-1.32021326 -1.42231457 -1.51787447  0.20347032 -0.25875209]]
# Latent representation shape: (228, 245) (should be [samples, nchannel])
# [b'critical_', b'equipment_', b'needs_', b'proper_', b'maintenance_']
# Audio sequence: []
# Length of phoneme sequence: 228
# [b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ih', b'ih', b'ih', b't', b'ih', b'ih', b'k', b'k', b'k', b'k', b'k', b'ax', b'ax', b'ax', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ih', b'ih', b'ih', b'ih', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'w', b'w', b'w', b'w', b'w', b'ih', b'ih', b'ih', b'p', b'p', b'p', b'p', b'm', b'm', b'm', b'm', b'm', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b't', b't', b'n', b'n', b'n', b'n', b'n', b'n', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'd', b'd', b'd', b'd', b'd', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'pau', b'pau', b'pau', b'pau', b'pau', b'p', b'p', b'p', b'p', b'p', b'r', b'r', b'r', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'er', b'er', b'er', b'er', b'er', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'n', b'n', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b'ax', b'ax', b'n', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'pau']
# ------------------------
#
# (330, 245)
#
# ------------------------
# For sentence 2:
# [[-0.23521639  0.3676989   0.23158901  0.24066901 -0.31339739]
#  [-0.27350544 -0.60284362 -0.7342924  -0.86732046 -1.05322474]
#  [ 1.6928193   1.67831134  1.38084623  0.25549834 -0.41478498]
#  [-2.03917842 -2.30760624 -2.22621226 -1.92853395 -0.43461446]
#  [-0.61992949 -0.86068972 -0.68912141 -0.90268772 -0.3274405 ]]
# Latent representation shape: (330, 245) (should be [samples, nchannel])
# [b'etiquette_', b'mandates_', b'compliance_', b'with_', b'existing_', b'regulations_']
# Audio sequence: []
# Length of phoneme sequence: 330
# [b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b't', b'ax', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b't', b't', b't', b't', b't', b't', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'ae', b'ae', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'd', b'd', b'd', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b't', b't', b't', b't', b't', b't', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'k', b'k', b'k', b'k', b'k', b'ax', b'ax', b'ax', b'm', b'm', b'm', b'm', b'm', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ay', b'ay', b'ay', b'ay', b'ay', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'pau', b'pau', b'pau', b'w', b'w', b'ih', b'ih', b'ih', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'pau', b'pau', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'g', b'g', b'g', b'g', b'g', b'g', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'ih', b'ih', b'ih', b'ih', b'ih', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b't', b't', b'ih', b'ih', b'ih', b'ih', b'ih', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'eh', b'eh', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'y', b'y', b'y', b'ax', b'ax', b'ax', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z']
# ------------------------
#
# (164, 245)
#
# ------------------------
# For sentence 3:
# [[ 1.13510639  1.27262321  2.00534583  1.51764694  0.47720724]
#  [-0.70433761 -0.87907695 -0.53069597  1.15699776 -1.03289535]
#  [ 0.00279323  0.23583315  0.24585644  1.65056913 -0.1944389 ]
#  [-1.50769305 -1.80193674 -1.90132882  0.16878171 -1.05268801]
#  [ 0.11248994 -0.3375327  -1.01449244  0.6181074   0.42288732]]
# Latent representation shape: (164, 245) (should be [samples, nchannel])
# [b'swing_', b'your_', b'arm_', b'as_', b'high_', b'as_', b'you_', b'can_']
# Audio sequence: []
# Length of phoneme sequence: 164
# [b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'w', b'w', b'w', b'w', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ng', b'ng', b'ng', b'ng', b'ng', b'y', b'y', b'y', b'y', b'y', b'ao', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'm', b'm', b'm', b'm', b'm', b'm', b'pau', b'pau', b'pau', b'pau', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'ay', b'ay', b'ay', b'ay', b'ay', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'y', b'y', b'y', b'y', b'uw', b'uw', b'uw', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'n', b'n', b'n', b'n']
# ------------------------
#
# (304, 245)
#
# ------------------------
# For sentence 4:
# [[-0.06326332 -0.96290932 -1.44401961 -1.7869953   0.49099688]
#  [-0.30512245 -0.30104789 -0.55454931 -0.73493595  0.93482132]
#  [-0.52966242 -0.54865187 -0.53099815 -1.29149229 -0.72182934]
#  [ 1.17773719  1.39496086  1.34916089  1.11799655  0.84675626]
#  [ 0.78526856  1.25246166  0.66362026  1.00266725  2.64940215]]
# Latent representation shape: (304, 245) (should be [samples, nchannel])
# [b'at_', b'twilight_', b'on_', b'the_', b'twelfth_', b'day_', b"we'll_", b'have_', b'chablis_']
# Audio sequence: []
# Length of phoneme sequence: 304
# [b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b't', b't', b'pau', b'pau', b'pau', b'pau', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b'w', b'w', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b't', b't', b't', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'n', b'n', b'n', b'n', b'n', b'n', b'dh', b'dh', b'dh', b'ax', b'ax', b'ax', b'ax', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b'w', b'w', b'eh', b'eh', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'f', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'pau', b'pau', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'pau', b'pau', b'pau', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'iy', b'iy', b'iy', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'pau', b'pau', b'pau', b'pau', b'pau', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'ax', b'ax', b'ax', b'ax', b'ax', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy']
# ------------------------
#
# (253, 245)
#
# ------------------------
# For sentence 5:
# [[ 0.10529698 -0.71438593 -0.8709092  -0.10465735  0.73593283]
#  [-0.80097209 -0.47896856 -0.43357539 -0.6246867   0.72707791]
#  [-1.08158911 -1.48255411 -1.74170931 -1.4306677  -0.69176212]
#  [ 0.09424847  0.70207306  0.26538781 -0.97057226 -0.73896293]
#  [-0.36065795 -1.13827371 -1.13209554 -1.07311501  0.36637099]]
# Latent representation shape: (253, 245) (should be [samples, nchannel])
# [b'nothing_', b'is_', b'as_', b'offensive_', b'as_', b'innocence_']
# Audio sequence: []
# Length of phoneme sequence: 253
# [b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'ih', b'ih', b'ih', b'ih', b'ih', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'ax', b'ax', b'ax', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'eh', b'eh', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'pau', b'pau', b'ih', b'ih', b'ih', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'ax', b'ax', b'ax', b'ax', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'ax', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'pau']
# ------------------------
#
# (239, 245)
#
# ------------------------
# For sentence 6:
# [[-0.7843159  -0.51343995 -0.6499835  -0.31804784 -0.13167384]
#  [-1.98605869 -1.75490544 -1.24271191 -1.24341169 -1.06882659]
#  [ 0.80385983  2.05539856  1.71433282  1.64779989  0.06994281]
#  [ 2.05790345  1.97309974  1.40185836  0.62480778  0.12228339]
#  [ 0.50201047  0.61138876  0.72276233  0.23923155 -0.77402322]]
# Latent representation shape: (239, 245) (should be [samples, nchannel])
# [b'those_', b'thieves_', b'stole_', b'thirty_', b'jewels_']
# Audio sequence: []
# Length of phoneme sequence: 239
# [b'dh', b'dh', b'dh', b'dh', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'th', b'th', b'th', b'th', b'th', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'v', b'v', b'v', b'v', b'v', b'v', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'd', b'd', b'd', b'd', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'jh', b'jh', b'jh', b'jh', b'jh', b'jh', b'jh', b'uw', b'uw', b'uw', b'uw', b'uw', b'ax', b'ax', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z']
# ------------------------
#
# (199, 245)
#
# ------------------------
# For sentence 7:
# [[ 0.09885395  0.06803884  0.35882441  0.50902027  1.00405608]
#  [-0.55873548 -0.39757202  0.19639697  0.39590567  0.98094348]
#  [-0.0622401  -0.57255198 -0.83591431 -0.99994636 -0.19326942]
#  [-0.76688172 -0.65720306 -0.50409799 -0.09815715 -0.75573463]
#  [-0.5604564  -1.66529188 -0.35685189 -0.5157805  -0.72597002]]
# Latent representation shape: (199, 245) (should be [samples, nchannel])
# [b'help_', b'celebrate_', b'your_', b'brother_', b'success_']
# Audio sequence: []
# Length of phoneme sequence: 199
# [b'hh', b'hh', b'hh', b'hh', b'hh', b'eh', b'eh', b'eh', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'eh', b'eh', b'eh', b'eh', b'eh', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ax', b'ax', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'r', b'r', b'r', b'r', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b't', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'ao', b'ao', b'r', b'r', b'r', b'r', b'r', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'r', b'r', b'r', b'r', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'z', b'z', b'z', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'ax', b'ax', b'ax', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's']
# ------------------------
#
# (178, 245)
#
# ------------------------
# For sentence 8:
# [[ 1.75220457  0.18567556  0.44650441  1.92537755  0.33232562]
#  [-1.72983798 -1.82271747 -2.21650146 -0.43557569 -0.75860588]
#  [-0.5332248  -0.52712433 -0.45879682 -1.0525838   0.14723092]
#  [-0.61819146  0.18571203  0.12522152 -0.19626479  0.29397415]
#  [-0.36891992  0.11492849  0.04440071 -0.38372712  1.21328142]]
# Latent representation shape: (178, 245) (should be [samples, nchannel])
# [b'will_', b'robin_', b'wear_', b'a_', b'yellow_', b'lily_']
# Audio sequence: []
# Length of phoneme sequence: 178
# [b'w', b'w', b'w', b'w', b'w', b'w', b'ih', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'r', b'r', b'r', b'r', b'r', b'r', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'b', b'b', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'eh', b'eh', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'eh', b'eh', b'eh', b'eh', b'l', b'l', b'ow', b'ow', b'ow', b'ow', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ih', b'ih', b'ih', b'ih', b'ih', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy']
# ------------------------
#
# (245, 245)
#
# ------------------------
# For sentence 9:
# [[ 0.20202685 -0.41678625 -0.37974644 -1.08439716 -0.94219973]
#  [ 0.15801876 -0.15313541 -0.40104575 -0.75330278 -0.52011833]
#  [ 0.55837264  0.39882017  0.38839073  0.32186059 -0.43370414]
#  [-0.15800488 -0.55881553 -0.43932907 -0.11255219 -0.17152421]
#  [ 1.36758672  1.3321263   1.00369483  0.0628521   0.32726179]]
# Latent representation shape: (245, 245) (should be [samples, nchannel])
# [b'a_', b'roll_', b'of_', b'wire_', b'lay_', b'lay_', b'near_', b'the_', b'wall_']
# Audio sequence: []
# Length of phoneme sequence: 245
# [b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'l', b'l', b'ah', b'v', b'v', b'v', b'v', b'v', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ey', b'ey', b'l', b'l', b'l', b'l', b'l', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'ih', b'ih', b'ih', b'ih', b'ih', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'ax', b'ax', b'ax', b'ax', b'ax', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'l', b'l', b'l', b'l']
# ------------------------
#
# (251, 245)
#
# ------------------------
# For sentence 10:
# [[-0.6730227  -1.02912026 -1.15239216 -1.00618683  0.25556536]
#  [ 2.59873758  3.16290559  3.13437339  4.0258648   0.02268117]
#  [ 1.8322308   1.55363731  1.4906615   1.64569335  0.45195142]
#  [-1.98735551 -1.01134619 -0.747107    1.75495174  0.75509916]
#  [-0.89725263 -0.33542646 -0.6214592   0.65306155 -0.11318062]]
# Latent representation shape: (251, 245) (should be [samples, nchannel])
# [b'aluminium_', b'cutlery_', b'can_', b'often_', b'be_', b'flimsy_']
# Audio sequence: []
# Length of phoneme sequence: 251
# [b'ae', b'ae', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'y', b'y', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'ih', b'ih', b'n', b'n', b'n', b'n', b'n', b'iy', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'pau', b'pau', b'pau', b'pau', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b't', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ae', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'ax', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'b', b'b', b'b', b'b', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'l', b'l', b'l', b'l', b'l', b'l', b'ih', b'ih', b'ih', b'ih', b'ih', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy']
# ------------------------
#
# (223, 245)
#
# ------------------------
# For sentence 11:
# [[-0.16381376 -0.84964174 -0.70202423  0.47000745 -0.77730178]
#  [ 0.64712766  0.44921589  0.09818076  0.32570997  0.88505704]
#  [-0.18380547  0.27252751 -0.36752384 -0.68763136  1.11811297]
#  [ 2.35178275  1.72104292  1.78454434  1.8302309  -0.0304819 ]
#  [ 0.5625956   0.56667442  0.81768191  0.62176548 -1.26320904]]
# Latent representation shape: (223, 245) (should be [samples, nchannel])
# [b'biblical_', b'scholars_', b'argue_', b'history_']
# Audio sequence: []
# Length of phoneme sequence: 223
# [b'b', b'b', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'b', b'b', b'b', b'b', b'b', b'l', b'l', b'l', b'l', b'ax', b'ax', b'ax', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ax', b'ax', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'k', b'k', b'k', b'k', b'k', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'aa', b'aa', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'g', b'g', b'g', b'g', b'g', b'g', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'pau', b'pau', b'pau', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'ih', b'ih', b'ih', b'ih', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b't', b't', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy']
# ------------------------
#
# (241, 245)
#
# ------------------------
# For sentence 12:
# [[ 0.38705901  0.7991667   0.89130399 -0.48658551  1.72037402]
#  [-1.36955888 -1.32796907 -0.60836312 -0.66279655 -0.55257014]
#  [-0.52217276 -0.45592045 -0.62443211 -0.39242381 -0.76284681]
#  [ 0.57899977  0.4328273  -0.18016896 -1.26282746 -0.64716657]
#  [-1.06798306 -1.11595743 -1.09979541 -0.77335507  0.73602532]]
# Latent representation shape: (241, 245) (should be [samples, nchannel])
# [b'get_', b'a_', b'calico_', b'cat_', b'to_', b'keep_', b'the_', b'rodents_', b'away_']
# Audio sequence: []
# Length of phoneme sequence: 241
# [b'g', b'g', b'g', b'g', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b't', b't', b't', b't', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ax', b'ax', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b't', b't', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b't', b't', b't', b't', b't', b'ax', b'ax', b'ax', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'iy', b'iy', b'p', b'p', b'p', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'dh', b'dh', b'dh', b'ax', b'ax', b'ax', b'ax', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'd', b'd', b'd', b'd', b'd', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b't', b't', b't', b't', b's', b's', b's', b's', b's', b's', b'ax', b'ax', b'ax', b'ax', b'ax', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey']
# ------------------------
#
# (312, 245)
#
# ------------------------
# For sentence 13:
# [[-0.76093457 -0.39798158 -0.36067077 -0.01645704  2.40925545]
#  [-0.12464921 -0.1093054  -0.09008817 -0.65846153  0.22362763]
#  [-1.5975727  -2.22914536 -2.16725313 -1.84060459 -0.38668583]
#  [ 1.19965907  0.80144783  0.32447765 -0.28596701 -0.06269814]
#  [-0.19846493 -0.13579398 -0.48429361  0.67414171 -0.98664319]]
# Latent representation shape: (312, 245) (should be [samples, nchannel])
# [b'only_', b'the_', b'most_', b'accomplished_', b'artists_', b'obtain_', b'popularity_']
# Audio sequence: []
# Length of phoneme sequence: 312
# [b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'l', b'iy', b'iy', b'dh', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b't', b'ax', b'ax', b'ax', b'ax', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'm', b'p', b'p', b'p', b'p', b'l', b'l', b'l', b'l', b'l', b'l', b'ih', b'ih', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b't', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'aa', b'aa', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b't', b't', b't', b't', b't', b't', b't', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b's', b's', b's', b's', b's', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'b', b'b', b'b', b'b', b'b', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'pau', b'pau', b'pau', b'pau', b'pau', b'p', b'p', b'p', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'p', b'p', b'p', b'p', b'p', b'p', b'y', b'y', b'y', b'y', b'y', b'ax', b'ax', b'ax', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'eh', b'eh', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ax', b'ax', b'ax', b't', b't', b't', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy']
# ------------------------
#
# (259, 245)
#
# ------------------------
# For sentence 14:
# [[-0.41152052 -0.35512554 -0.29178788 -0.237245    0.71886546]
#  [ 1.78093312  1.44350064  1.13127285  1.62933297  0.42358607]
#  [-1.22807553 -1.71584535 -1.66729184 -1.13117808 -0.43804532]
#  [ 0.65214383  1.01195852  1.14240815  1.45230835 -1.09192011]
#  [ 2.0414419   1.96301192  1.42558972  1.36277329  0.06903425]]
# Latent representation shape: (259, 245) (should be [samples, nchannel])
# [b'barb_', b'gold_', b'bracelet_', b'was_', b'a_', b'graduation_', b'present_']
# Audio sequence: []
# Length of phoneme sequence: 259
# [b'b', b'b', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'b', b'b', b'b', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'd', b'd', b'd', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'l', b'l', b'l', b'l', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b't', b't', b't', b'pau', b'pau', b'pau', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'aa', b'aa', b'aa', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'ax', b'ax', b'ax', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'jh', b'jh', b'jh', b'jh', b'jh', b'jh', b'jh', b'jh', b'jh', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'ax', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'r', b'r', b'r', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'ax', b'ax', b'n', b'n', b'n', b't', b't', b't']
# ------------------------
#
# (243, 245)
#
# ------------------------
# For sentence 15:
# [[ 1.36461345  0.52625408  1.29449972  2.50671176 -1.02751505]
#  [-0.22686709  0.26670467 -0.37238793 -0.40403504  0.60442474]
#  [-0.14921721 -0.50743878 -1.46103759 -0.75380311 -0.90904896]
#  [-0.47197694 -0.86500373 -0.94723049  0.64845905 -0.38416188]
#  [-0.59569594 -0.53317757 -0.06224965  0.56433448 -0.44363337]]
# Latent representation shape: (243, 245) (should be [samples, nchannel])
# [b'help_', b'greg_', b'to_', b'pick_', b'a_', b'peck_', b'of_', b'potatoes_']
# Audio sequence: []
# Length of phoneme sequence: 243
# [b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'l', b'l', b'l', b'l', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'r', b'r', b'r', b'r', b'r', b'r', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'g', b'g', b'g', b'g', b'g', b'g', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b'ax', b'ax', b'ax', b'ax', b'ax', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'pau', b'pau', b'pau', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ah', b'ah', b'v', b'v', b'v', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'ax', b'ax', b'ax', b'ax', b'ax', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b't', b't', b't', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z']
# ------------------------
#
# (322, 245)
#
# ------------------------
# For sentence 16:
# [[ 2.56161443  2.13447116  2.00915596  0.65704552 -0.20635565]
#  [ 0.10481432  0.32804298  0.02639983 -0.63747929 -0.29001714]
#  [ 0.17249804 -0.93022979 -1.08906552 -1.41642604 -0.99881879]
#  [ 0.25563217  0.33425535  0.12507953 -0.58168308  0.62358693]
#  [-0.45438598  0.29179092  0.60556131  0.60202394  0.69042603]]
# Latent representation shape: (322, 245) (should be [samples, nchannel])
# [b'catastrophic_', b'economic_', b'cutbacks_', b'neglect_', b'the_', b'poor_']
# Audio sequence: []
# Length of phoneme sequence: 322
# [b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b't', b't', b't', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b'r', b'r', b'r', b'r', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'f', b'f', b'f', b'f', b'f', b'ih', b'ih', b'ih', b'ih', b'ih', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'm', b'm', b'm', b'm', b'm', b'm', b'ih', b'ih', b'ih', b'ih', b'ih', b'k', b'k', b'k', b'pau', b'pau', b'pau', b'pau', b'pau', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b't', b't', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'ax', b'ax', b'ax', b'ax', b'ax', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'l', b'l', b'l', b'l', b'l', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b't', b't', b't', b't', b't', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'dh', b'dh', b'dh', b'ax', b'ax', b'ax', b'ax', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r']
# ------------------------
#
# (285, 245)
#
# ------------------------
# For sentence 17:
# [[-0.38731037 -1.06890934 -1.37547523 -1.03614154 -1.11132883]
#  [ 0.80214508  0.86129044  1.33233012  0.91139116 -0.87865875]
#  [-1.68049872 -1.22803432 -1.00349107 -0.4904727  -1.34075242]
#  [ 0.35255933  0.44847081  0.38102416  0.91291447 -0.44750143]
#  [-2.18080508 -2.01412457 -1.91315039 -1.63024199 -1.06073084]]
# Latent representation shape: (285, 245) (should be [samples, nchannel])
# [b'most_', b'young_', b'rabbits_', b'rise_', b'early_', b'every_', b'morning_']
# Audio sequence: []
# Length of phoneme sequence: 285
# [b'm', b'm', b'm', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b't', b't', b't', b't', b'y', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ng', b'ng', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'b', b'b', b'b', b'b', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b't', b't', b't', b't', b't', b't', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'pau', b'pau', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'er', b'er', b'er', b'er', b'er', b'iy', b'iy', b'iy', b'iy', b'iy', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'r', b'r', b'r', b'r', b'r', b'r', b'n', b'n', b'n', b'n', b'n', b'n', b'ih', b'ih', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng']
# ------------------------
#
# (205, 245)
#
# ------------------------
# For sentence 18:
# [[ 0.15173275  0.31645034  0.10394264 -0.12839038 -1.36121791]
#  [ 0.50341343  0.44689914  0.79804106  0.10850517 -0.14474125]
#  [ 0.98064764  0.60443019  0.55751035  0.67772327  0.05556429]
#  [ 2.15746338  2.08313613  2.00250546  0.63574514 -0.34971158]
#  [ 1.12761271  1.18578176  0.85400988  0.0576764  -0.7318971 ]]
# Latent representation shape: (205, 245) (should be [samples, nchannel])
# [b'did_', b'dad_', b'do_', b'academic_', b'bidding_']
# Audio sequence: []
# Length of phoneme sequence: 205
# [b'd', b'd', b'd', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'pau', b'd', b'd', b'd', b'd', b'd', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'd', b'd', b'd', b'd', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'k', b'k', b'k', b'k', b'k', b'k', b'ax', b'ax', b'ax', b'ax', b'ax', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'm', b'm', b'm', b'm', b'm', b'm', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'k', b'k', b'k', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'b', b'b', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'd', b'd', b'd', b'ih', b'ih', b'ih', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng']
# ------------------------
#
# (139, 245)
#
# ------------------------
# For sentence 19:
# [[ 0.90171131  0.69379422  0.79831032  0.72715217  1.39203542]
#  [ 0.94219501  1.17136625  0.71157451  0.27805672  0.10975986]
#  [ 0.2510808   0.9286936   1.24914409  0.46937754 -0.51802032]
#  [-0.59989122  0.17770586  0.45951282 -0.03895438 -0.29633529]
#  [-0.30605432 -0.1617803  -0.11446974 -0.18582138  0.47280368]]
# Latent representation shape: (139, 245) (should be [samples, nchannel])
# [b'she_', b'is_', b'thinner_', b'than_', b'i_', b'am_']
# Audio sequence: []
# Length of phoneme sequence: 139
# [b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'th', b'th', b'th', b'th', b'th', b'ih', b'ih', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'dh', b'dh', b'dh', b'dh', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'n', b'n', b'n', b'n', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'pau']
# ------------------------
#
# (237, 245)
#
# ------------------------
# For sentence 20:
# [[ 0.03924849  0.78883494  0.68233886 -0.6467509   0.12405044]
#  [ 0.99233912  0.53909377  0.59762622 -0.2162286  -1.08685349]
#  [-0.32376405 -0.79792919 -0.53722935 -1.34106876 -0.91667998]
#  [-0.22755133  0.01432489  0.2312614   0.74842226  0.90166362]
#  [ 1.46925902  2.04603152  2.10490748  1.09065395  0.9169269 ]]
# Latent representation shape: (237, 245) (should be [samples, nchannel])
# [b'alimony_', b'harms_', b'a_', b'divorced_', b'man_', b'wealth_']
# Audio sequence: []
# Length of phoneme sequence: 237
# [b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ax', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'n', b'n', b'n', b'n', b'n', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'aa', b'aa', b'aa', b'aa', b'aa', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'm', b'm', b'm', b'm', b'm', b'm', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'pau', b'pau', b'pau', b'pau', b'd', b'd', b'd', b'd', b'ih', b'ih', b'ih', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b't', b't', b'pau', b'pau', b'm', b'm', b'm', b'm', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'w', b'w', b'w', b'w', b'w', b'w', b'w', b'eh', b'eh', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th']
# ------------------------
#
# (239, 245)
#
# ------------------------
# For sentence 21:
# [[-0.75517212 -0.39656807 -0.52899    -0.76719157  0.20109832]
#  [-0.57203955  0.0251531   0.54418378  0.89791161  0.26733282]
#  [ 1.56124676  1.70813029  1.92376532  0.69160113  1.12048504]
#  [-0.9474745  -0.75088539 -1.22097106 -0.52320211 -0.185815  ]
#  [-0.76948141 -0.37019608 -0.68433457  0.22647915  1.06798597]]
# Latent representation shape: (239, 245) (should be [samples, nchannel])
# [b'are_', b'your_', b'grades_', b'higher_', b'or_', b'lower_', b'than_', b'nancy_']
# Audio sequence: []
# Length of phoneme sequence: 239
# [b'aa', b'aa', b'aa', b'r', b'r', b'r', b'r', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'ao', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'r', b'r', b'r', b'r', b'r', b'r', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'd', b'd', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'pau', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'l', b'l', b'l', b'l', b'l', b'l', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'ow', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'ae', b'ae', b'ae', b'ae', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z']
# ------------------------
#
# (236, 245)
#
# ------------------------
# For sentence 22:
# ...
#  [ 0.35781403  1.23409998  1.09044302  0.72975417 -0.82912872]
#  [-1.08954355  1.52048517  1.40644543  0.82267623  0.49824731]
#  [-1.01661805 -1.61019269 -1.52185504 -1.2424879  -0.80502976]]
# Latent representation shape: (243, 245) (should be [samples, nchannel])
# [b'addition_', b'and_', b'subtraction_', b'are_', b'learned_', b'skills_']
# Audio sequence: []
# Length of phoneme sequence: 243
# [b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'd', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'ax', b'ax', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'ae', b'ae', b'ae', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'd', b'd', b'pau', b'pau', b's', b's', b's', b's', b's', b's', b'ax', b'ax', b'ax', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b't', b't', b't', b't', b't', b't', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'k', b'k', b'k', b'k', b'k', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'n', b'n', b'n', b'n', b'd', b'd', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'k', b'k', b'k', b'k', b'k', b'k', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z']
# ------------------------
#
# (306, 245)
#
# ------------------------
# For sentence 43:
# [[-0.90534488 -0.99506497 -1.26597895 -1.01115212 -0.3591939 ]
#  [-0.45524084 -1.1964902  -1.53207578 -1.40583286 -0.76264857]
#  [-0.73589071 -1.31429704 -1.24315239 -0.85849662  0.45147094]
#  [ 0.06601751  0.89004907  0.33417445  0.13222287 -0.40325872]
#  [-0.43300118 -1.40127365 -1.62777109 -1.39843316 -1.37195504]]
# Latent representation shape: (306, 245) (should be [samples, nchannel])
# [b'catastrophic_', b'economic_', b'cutbacks_', b'neglect_', b'the_', b'poor_']
# Audio sequence: []
# Length of phoneme sequence: 306
# [b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b't', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b't', b't', b'r', b'r', b'r', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ax', b'ax', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'aa', b'm', b'm', b'm', b'm', b'm', b'm', b'ih', b'ih', b'ih', b'ih', b'ih', b'k', b'k', b'k', b'k', b'k', b'k', b'pau', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b'b', b'b', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'n', b'n', b'n', b'n', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'g', b'g', b'g', b'g', b'g', b'g', b'g', b'l', b'l', b'l', b'l', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'k', b'k', b'k', b'k', b'k', b'k', b't', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b'dh', b'dh', b'ax', b'ax', b'ax', b'ax', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'p', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'uh', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r']
# ------------------------
#
# (156, 245)
#
# ------------------------
# For sentence 44:
# [[ 0.13463046  0.4313577   0.62763162  0.44886079  0.8760408 ]
#  [-0.59455095 -0.71671677 -0.69133636 -1.27286123 -0.4011259 ]
#  [-1.01881059 -0.74388494 -0.74147255 -0.56330534 -0.9440143 ]
#  [-1.32284957 -1.777792   -1.27097766 -0.9677934  -1.47902218]
#  [-0.94621685 -0.12694895 -0.25969781 -0.25771457 -0.93962074]]
# Latent representation shape: (156, 245) (should be [samples, nchannel])
# [b'alfalfa_', b'is_', b'healthy_', b'for_', b'you_']
# Audio sequence: []
# Length of phoneme sequence: 156
# [b'ae', b'ae', b'ae', b'ae', b'ae', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'eh', b'eh', b'eh', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'th', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'ao', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw']
# ------------------------
#
# (220, 245)
#
# ------------------------
# For sentence 45:
# [[-1.14590506 -0.72951768 -0.72781204  0.26245713  0.1323038 ]
#  [ 1.43890054  0.89510081  1.0804776   1.46072853  0.03479206]
#  [-0.8204859  -1.23205466 -1.40568508 -1.5940976  -0.74233928]
#  [ 1.25776795  1.63811957  1.43384227  0.90983435 -0.69963631]
#  [-0.01133694 -0.20131871 -0.55798301 -1.12259677 -0.77635239]]
# Latent representation shape: (220, 245) (should be [samples, nchannel])
# [b'help_', b'celebrate_', b'your_', b'brother_', b'success_']
# Audio sequence: []
# Length of phoneme sequence: 220
# [b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'eh', b'eh', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'p', b'p', b'p', b'p', b'p', b'p', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ax', b'ax', b'ax', b'b', b'b', b'b', b'b', b'r', b'r', b'r', b'r', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b't', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'y', b'ao', b'ao', b'r', b'r', b'r', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'b', b'r', b'r', b'r', b'r', b'r', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'dh', b'dh', b'dh', b'dh', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'ax', b'ax', b'ax', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b'eh', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's']
# ------------------------
#
# (124, 245)
#
# ------------------------
# For sentence 46:
# [[-0.24234196  0.08735328  0.11637932  0.38908705 -0.30709205]
#  [-0.27362467 -0.69852844 -0.96588628 -1.12960411  0.10732723]
#  [-0.35563554 -0.18409251 -0.07193441  0.48438013  0.1975813 ]
#  [-0.42855023 -0.16477695 -0.27868829 -0.23721524 -0.02588338]
#  [ 0.79972136  0.70100877  0.90589097  1.37980309 -0.88693778]]
# Latent representation shape: (124, 245) (should be [samples, nchannel])
# [b'this_', b'was_', b'easy_', b'for_', b'us_']
# Audio sequence: []
# Length of phoneme sequence: 124
# [b'dh', b'dh', b'dh', b'dh', b'ih', b'ih', b'ih', b'ih', b'ih', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'w', b'w', b'w', b'aa', b'aa', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'ao', b'ao', b'ao', b'ao', b'ao', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'r', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's']
# ------------------------
#
# (252, 245)
#
# ------------------------
# For sentence 47:
# [[-0.55869399 -0.65597231 -0.407125   -0.50369457  0.11684076]
#  [ 3.20279322  3.2594946   2.67643781  2.31991654 -1.51973732]
#  [ 7.85443792  8.59252815  7.09792092  7.81460618  0.99901973]
#  [ 3.75942274  5.03109007  3.49824552  4.31138203  0.66023029]
#  [-0.43933413 -0.71246641 -0.69866612 -0.41533678 -0.68141941]]
# Latent representation shape: (252, 245) (should be [samples, nchannel])
# [b'the_', b'museum_', b'hires_', b'musicians_', b'every_', b'evening_']
# Audio sequence: []
# Length of phoneme sequence: 252
# [b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'dh', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'y', b'y', b'y', b'y', b'y', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'hh', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'ay', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'm', b'm', b'm', b'm', b'm', b'm', b'y', b'y', b'y', b'y', b'uw', b'uw', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'ih', b'ih', b'ih', b'ih', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'ax', b'ax', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'pau', b'pau', b'pau', b'pau', b'pau', b'eh', b'v', b'v', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'v', b'v', b'v', b'v', b'v', b'v', b'v', b'n', b'n', b'n', b'n', b'ih', b'ih', b'ih', b'ih', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng', b'ng']
# ------------------------
#
# (219, 245)
#
# ------------------------
# For sentence 48:
# [[-0.83900949  0.4570386   0.67600361  0.82658432  0.48606717]
#  [-0.55389616 -0.47596234 -0.97255661 -0.99748607 -0.46620127]
#  [ 0.72556321  0.31915049  0.35306787  0.17201728  0.0904902 ]
#  [ 0.82196311  2.54673754  2.43158363  2.05077597  0.2863142 ]
#  [-0.70251195 -0.70154389 -0.78674076 -1.16592769 -0.93257684]]
# Latent representation shape: (219, 245) (should be [samples, nchannel])
# [b'aluminium_', b'cutlery_', b'can_', b'often_', b'be_', b'flimsy_']
# Audio sequence: []
# Length of phoneme sequence: 219
# [b'ae', b'ae', b'ae', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'y', b'y', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'ih', b'ih', b'n', b'n', b'n', b'n', b'n', b'iy', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'm', b'm', b'm', b'm', b'm', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b't', b't', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'er', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'ae', b'ae', b'ae', b'ae', b'ae', b'ae', b'n', b'n', b'n', b'n', b'n', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'ao', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'b', b'b', b'b', b'b', b'b', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'f', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'l', b'ih', b'ih', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy', b'iy']
# ------------------------
#
# (244, 245)
#
# ------------------------
# For sentence 49:
# [[-1.08004934 -1.26705829 -1.62715533 -1.77198911  1.44229673]
#  [-0.86252607 -0.68178412 -0.34796247 -0.16443011 -1.00279271]
#  [ 0.23636594  0.19424369  0.02215703  0.68532918 -0.16569434]
#  [-0.16094255  0.26561105  0.31736533 -0.04059277  0.45466373]
#  [-0.63391423 -0.99506672 -0.99252919 -0.56115799  1.12877147]]
# Latent representation shape: (244, 245) (should be [samples, nchannel])
# [b'stimulating_', b'discussions_', b'keep_', b'students_', b'attention_']
# Audio sequence: []
# Length of phoneme sequence: 244
# [b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b'ih', b'ih', b'ih', b'ih', b'ih', b'ih', b'm', b'm', b'm', b'm', b'm', b'm', b'm', b'y', b'y', b'y', b'y', b'y', b'ax', b'ax', b'ax', b'ax', b'ax', b'l', b'l', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b'ey', b't', b't', b'ih', b'ih', b'ng', b'ng', b'd', b'd', b'd', b'ih', b'ih', b'ih', b'ih', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b'k', b'k', b'k', b'k', b'k', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'ah', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'z', b'k', b'k', b'k', b'k', b'k', b'k', b'k', b'iy', b'iy', b'iy', b'iy', b'iy', b'p', b'p', b'p', b'p', b'p', b'p', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b's', b't', b't', b't', b't', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'uw', b'd', b'd', b'ax', b'ax', b'ax', b'ax', b'ax', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b't', b't', b't', b's', b's', b's', b's', b's', b'ax', b'ax', b'ax', b'ax', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b't', b'eh', b'eh', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'n', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'sh', b'ax', b'ax', b'ax', b'ax', b'ax', b'ax', b'pau', b'pau', b'pau', b'pau', b'pau', b'pau']
# ------------------------
#
# 50
# 150
# 150
